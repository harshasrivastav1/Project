# %% [markdown]
# <a href="https://colab.research.google.com/github/harshasrivastav1/Project/blob/main/Retail_Insights_from_Superstore_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Load the necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Import the dataset
df=pd.read_csv("/content/drive/MyDrive/1719219914-Analysis of Super Store - DA (1).csv")

# %%
# Reading first five rows of dataset
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
# Reading last five rows of dataset
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
# Showing information about the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
# Showing statistics for Dataframe
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Postal Code'].plot(kind='hist', bins=20, title='Postal Code')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
# Showing size of dataset (rows, columns)
df.shape
# Out:
# (9994, 13)

# %%
# Showing datatype of the given dataset
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
# Checking for null values
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
# Checking for number of unique values in every column
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
#df.drop('Postal Code', axis=1, inplace = True)

# %%
df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
# Showing data in floating values
(df['Ship Mode'].value_counts()/len(df['Ship Mode']))*100
# Out:
# Ship Mode
# Standard Class    59.715829
# Second Class      19.461677
# First Class       15.389234
# Same Day           5.433260
# Name: count, dtype: float64

# %%
((df['Ship Mode'].value_counts()/len(df['Ship Mode']))*100).plot(kind="bar",color= "violet")
# Out:
# <Axes: xlabel='Ship Mode'>

# %%
df['Segment'].value_counts()
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64

# %%
# Showing data in floating values
(df['Segment'].value_counts()/len(df['Ship Mode']))*100
# Out:
# Segment
# Consumer       51.941165
# Corporate      30.218131
# Home Office    17.840704
# Name: count, dtype: float64

# %%
((df['Segment'].value_counts()/len(df['Ship Mode']))*100).plot(kind='bar', color='blue')
# Out:
# <Axes: xlabel='Segment'>

# %%
df['Category'].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
# Showing data in floating values
(df['Category'].value_counts()/len(df['Ship Mode']))*100
# Out:
# Category
# Office Supplies    60.296178
# Furniture          21.222734
# Technology         18.481089
# Name: count, dtype: float64

# %%
((df['Category'].value_counts()/len(df['Ship Mode']))*100).plot(kind='bar', color='orange')
# Out:
# <Axes: xlabel='Category'>

# %%
df['Sub-Category'].value_counts()
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %%
# Showing data in floating values
(df['Sub-Category'].value_counts()/len(df['Ship Mode']))*1
# Out:
# Sub-Category
# Binders        0.152391
# Paper          0.137082
# Furnishings    0.095757
# Phones         0.088953
# Storage        0.084651
# Art            0.079648
# Accessories    0.077547
# Chairs         0.061737
# Appliances     0.046628
# Labels         0.036422
# Tables         0.031919
# Envelopes      0.025415
# Bookcases      0.022814
# Fasteners      0.021713
# Supplies       0.019011
# Machines       0.011507
# Copiers        0.006804
# Name: count, dtype: float64

# %%
((df['Sub-Category'].value_counts()/len(df['Ship Mode']))*100).plot(kind='bar', color='cyan')
# Out:
# <Axes: xlabel='Sub-Category'>

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
 sns.catplot(x='Category',y='Profit',data=df,col="Region")

# %%
sns.barplot(x=df.Discount, y=df.Profit)
# Out:
# <Axes: xlabel='Discount', ylabel='Profit'>

# %%
sns.barplot(x=df.Region, y=df.Sales)
# Out:
# <Axes: xlabel='Region', ylabel='Sales'>

# %%
sns.barplot(x=df.Region, y=df.Profit, hue=df.Category)
# Out:
# <Axes: xlabel='Region', ylabel='Profit'>

# %%
 sns.barplot(x=df.Region, y=df.Profit, hue=df.Segment)
# Out:
# <Axes: xlabel='Region', ylabel='Profit'>

# %%
dataplot = df.groupby(['State'])['Profit'].sum()
dataplot.plot.bar(figsize=(20,10),color='purple')
# Out:
# <Axes: xlabel='State'>

# %%
dataplot = df.groupby(['State']).Discount.sum()
plt.xlabel('States')
plt.ylabel('Discount')
dataplot.plot.bar(figsize=(20,10),color='maroon')
# Out:
# <Axes: xlabel='State', ylabel='Discount'>

# %%
#Profit analysis based on region
df.groupby("Region")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='Region'>

# %%
#Sales analysis based on region
df.groupby("Region")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Region'>

# %%
df.groupby("Category")["Profit"].sum().plot.pie()
# Out:
# <Axes: ylabel='Profit'>
